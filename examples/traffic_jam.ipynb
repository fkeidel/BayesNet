# %%
# plots output from 'examples\traffic_jam_variable_elimination.cpp'

import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt(data_path + 'traffic.csv', delimiter=',', skip_header=1)

x = range(len(data))

plt.plot(x, data[:,0], 'r-', label='P(camera|slow)')
plt.plot(x, data[:,1], 'g-', label='P(radar|slow)')
plt.plot(x, data[:,2], 'b-', label='P(traffic|camera,radar)')

plt.legend(loc='best')
plt.show()
